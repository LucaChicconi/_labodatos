# %%
import seaborn as sns
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt

from scipy import stats
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from formulaic import model_matrix

# %%
#import os
#print(pwd)
#os.chdir('./notebooks')

# %% [markdown]
# # Limpieza de Datos

# %% [markdown]
# En Python, las funciones y paquetes para trabajar con datos no están pensadas para poder hacerlas "sin saber nada de Python". Al contrario, muchas operaciones sencillas de DataFrames requieren conocer técnicas de programación en Python. Vamos a ver algunas en esta clase, principalmente estas cuatro:

# %% [markdown]
# ## 1. Diccionarios
# ## 2. Encadenamiento de métodos
# ## 3. Funciones lambda
# ## 4. Definición de listas por comprensión

# %% [markdown]
# **Ejercicio 1.** En el dataset de vinos de la última clase, renombrar la columna "od280/od315_of_diluted_wines" a "od280_od315_of_diluted_wines".

# %%
from sklearn.datasets import load_wine
wine = load_wine(as_frame=True)
wineData = wine.data
wineData.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %% [markdown]
# Hay esencialmente dos formas de renombrar columnas:
# 1. Utilizar `rename()`
# 2. Modificar la lista de nombres de columnas `dataframe.columns`
#
# Comenzamos con `rename()`.

# %%
pd.DataFrame.rename(wineData,columns={"od280/od315_of_diluted_wines":"od280_od315_of_diluted_wines"})

# O help(pd.DataFrame.rename)
# O wineData.rename??
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280_od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %% [markdown]
# Vemos que podemos renombrar columnas utilizando `columns: dict-like or function`

# %% [markdown]
# ## 1. Diccionarios
# Los diccionarios se utilizan para almacenar valores de datos en pares clave:valor.
#
# Un diccionario es una colección ordenada, modificable y que no permite duplicados.

# %%
# Ejemplo
dict = { "hola" : "Expresión de saludo utilizada entre dos o más personas de trato familiar", "cinco" : 5, "dias" : ["lunes", "martes", "miercoles"]}

# %%
dict["cinco"]
# Out:
# 5

# %%
# Ejemplo
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %% [markdown]
# Para renombrar una columna, usamos rename(columns = _DICT_) y un diccionario con "nombre viejo" como claves y "nombre nuevo" como valores.

# %%
wineData.rename(columns = {"od280/od315_of_diluted_wines" : "od280_od315_of_diluted_wines"})  # No es necesario renombrar todas las columnas, podemos renombrar las que querramos.
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280_od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
# Cambió algo?
wineData
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %%
# Podemos guardar los cambios en el mismo DataFrame o en uno nuevo
wineClean = wineData.rename(columns = {"od280/od315_of_diluted_wines" : "od280_od315_of_diluted_wines"})
wineClean.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280_od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0

# %% [markdown]
# **Nota:** también existe la opción "inplace = True" pero no está recomendada (por ejemplo, no permite encadenar comandos).

# %% [markdown]
# ### `rename` con funciones
#
# También podemos usar funciones para renombrar columnas (Python permite pasar funciones como parámetros).
#
# **Ejemplo:** Pasar todos los nombres de columnas a mayúsculas.

# %%
# Para pasar un string a mayusculas utilizamo str.upper
str.upper("hola")
# Out:
# 'HOLA'

# %% [markdown]
# ¿Cómo lo usarian para renombrar nuestras variables?

# %%
# Así?
wineData.rename(columns = str.upper)
# o así?
#wineData.rename(columns = str.upper())
# Out:
#      ALCOHOL  MALIC_ACID   ASH  ALCALINITY_OF_ASH  MAGNESIUM  TOTAL_PHENOLS  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      FLAVANOIDS  NONFLAVANOID_PHENOLS  PROANTHOCYANINS  COLOR_INTENSITY   HUE  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280/OD315_OF_DILUTED_WINES  PROLINE
# 0                            3.92   1065.0
# 1                            3.40   1050.0
# 2                            3.17   1185.0
# 3                            3.45   1480.0
# 4                            2.93    735.0
# ..                            ...      ...
# 173                          1.74    740.0
# 174                          1.56    750.0
# 175                          1.56    835.0
# 176                          1.62    840.0
# 177                          1.60    560.0
#
# [178 rows x 13 columns]

# %% [markdown]
# <details>
# <summary>Click para ver la respuesta</summary>
#
# Le pasamos el nombre de la función, por eso va sin los paréntesis.
#
# Si la pasamos con paréntesis le estaríamos pasando el resultado de evaluar la función sin parámetros.
# </details>

# %% [markdown]
# ### Ejercicio
#
# Definiendo tu propia función, agregar en todos los nombres de columna "_2026" al final del nombre.

# %%
def agregar2026 (data):
    return data.rename(columns= lambda x : x + "_2026")
agregar2026(wineData)
# Out:
#      alcohol_2026  malic_acid_2026  ash_2026  alcalinity_of_ash_2026  \
# 0           14.23             1.71      2.43                    15.6
# 1           13.20             1.78      2.14                    11.2
# 2           13.16             2.36      2.67                    18.6
# 3           14.37             1.95      2.50                    16.8
# 4           13.24             2.59      2.87                    21.0
# ..            ...              ...       ...                     ...
# 173         13.71             5.65      2.45                    20.5
# 174         13.40             3.91      2.48                    23.0
# 175         13.27             4.28      2.26                    20.0
# 176         13.17             2.59      2.37                    20.0
# 177         14.13             4.10      2.74                    24.5
#
#      magnesium_2026  total_phenols_2026  flavanoids_2026  \
# 0             127.0                2.80             3.06
# 1             100.0                2.65             2.76
# 2             101.0                2.80             3.24
# 3             113.0                3.85             3.49
# 4             118.0                2.80             2.69
# ..              ...                 ...              ...
# 173            95.0                1.68             0.61
# 174           102.0                1.80             0.75
# 175           120.0                1.59             0.69
# 176           120.0                1.65             0.68
# 177            96.0                2.05             0.76
#
#      nonflavanoid_phenols_2026  proanthocyanins_2026  color_intensity_2026  \
# 0                         0.28                  2.29                  5.64
# 1                         0.26                  1.28                  4.38
# 2                         0.30                  2.81                  5.68
# 3                         0.24                  2.18                  7.80
# 4                         0.39                  1.82                  4.32
# ..                         ...                   ...                   ...
# 173                       0.52                  1.06                  7.70
# 174                       0.43                  1.41                  7.30
# 175                       0.43                  1.35                 10.20
# 176                       0.53                  1.46                  9.30
# 177                       0.56                  1.35                  9.20
#
#      hue_2026  od280/od315_of_diluted_wines_2026  proline_2026
# 0        1.04                               3.92        1065.0
# 1        1.05                               3.40        1050.0
# 2        1.03                               3.17        1185.0
# 3        0.86                               3.45        1480.0
# 4        1.04                               2.93         735.0
# ..        ...                                ...           ...
# 173      0.64                               1.74         740.0
# 174      0.70                               1.56         750.0
# 175      0.59                               1.56         835.0
# 176      0.60                               1.62         840.0
# 177      0.61                               1.60         560.0
#
# [178 rows x 13 columns]

# %% [markdown]
# ## 2. Encadenar métodos

# %% [markdown]
# ### 2.a Datos faltantes

# %% [markdown]
# **Ejercicio 2.** En la base de dato de pingüinos, eliminar las filas con datos faltantes, y renumerar los índices comenzando en 1.

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins_limpia = penguins.dropna()
penguins_limpia.index = range(1, len(penguins_limpia)+1)

penguins_limpia
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 329  Gentoo     Biscoe            47.2           13.7              214.0
# 330  Gentoo     Biscoe            46.8           14.3              215.0
# 331  Gentoo     Biscoe            50.4           15.7              222.0
# 332  Gentoo     Biscoe            45.2           14.8              212.0
# 333  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 1         3750.0    Male
# 2         3800.0  Female
# 3         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 329       4925.0  Female
# 330       4850.0  Female
# 331       5750.0    Male
# 332       5200.0  Female
# 333       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## Primero: ¿qué son los datos faltantes?

# %% [markdown]
# ¿Qué significa un valor faltante? Es un dato que por distintos motivos no fue ingresado (por ejemplo si juntamos datos de distintas fuentes, en alguna de las fuentes esa información puede no estar disponible).
#
# Los datos faltantes son algo típico de cualquier pipeline de análisis de datos. En general los paquetes estadísticos (pandas, dplyr, etc) tratan de facilitar el manejo de estos tipos de datos. En Pandas, se utiliza la expresión NaN (Not a number) o NA que viene del mundo R (Not available)

# %%
# Vamos a trabajar con una base de eficiencia del sueño
datos = pd.read_csv("Sleep_efficiency_cleaning.csv")
datos
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      12         0.0
# 1                       28                      53         3.0
# 2                       70                      10         1.0
# 3                       25                      52         3.0
# 4                       55                      18         3.0
# ..                     ...                     ...         ...
# 457                     63                      15         1.0
# 458                     60                      22         3.0
# 459                     67                      13         4.0
# 460                     52                      20         0.0
# 461                     20                      53         3.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 0                     0.0                  0.0            Yes
# 1                     0.0                  3.0            Yes
# 2                     0.0                  0.0             No
# 3                    50.0                  5.0            Yes
# 4                     0.0                  3.0             No
# ..                    ...                  ...            ...
# 457                  75.0                  0.0            Yes
# 458                   0.0                  0.0             No
# 459                   0.0                  1.0             No
# 460                  50.0                  0.0             No
# 461                   0.0                  1.0            Yes
#
#      Exercise frequency
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   1.0
# 4                   3.0
# ..                  ...
# 457                 2.0
# 458                 3.0
# 459                 3.0
# 460                 0.0
# 461                 3.0
#
# [462 rows x 15 columns]

# %% [markdown]
# Para poder acceder a los datos faltantes, podemos utilizar la función `isna()`
#
# ¿Cómo la usamos? ¿Qué nos devuelve?

# %%
datos.isna()
# Out:
#         ID    Age  Gender  Bedtime  Wakeup time  Sleep duration  \
# 0    False  False   False    False        False           False
# 1    False  False   False    False        False           False
# 2    False  False   False    False        False           False
# 3    False  False   False    False        False           False
# 4    False  False   False    False        False           False
# ..     ...    ...     ...      ...          ...             ...
# 457  False  False   False    False        False           False
# 458  False  False   False    False        False           False
# 459  False  False   False    False        False           False
# 460  False  False   False    False        False           False
# 461  False  False   False    False        False           False
#
#      Sleep efficiency  REM sleep percentage  Deep sleep percentage  \
# 0               False                 False                  False
# 1               False                 False                  False
# 2               False                 False                  False
# 3               False                 False                  False
# 4               False                 False                  False
# ..                ...                   ...                    ...
# 457             False                 False                  False
# 458             False                 False                  False
# 459             False                 False                  False
# 460             False                 False                  False
# 461             False                 False                  False
#
#      Light sleep percentage  Awakenings  Caffeine consumption  \
# 0                     False       False                 False
# 1                     False       False                 False
# 2                     False       False                 False
# 3                     False       False                 False
# 4                     False       False                 False
# ..                      ...         ...                   ...
# 457                   False       False                 False
# 458                   False       False                 False
# 459                   False       False                 False
# 460                   False       False                 False
# 461                   False       False                 False
#
#      Alcohol consumption  Smoking status  Exercise frequency
# 0                  False           False               False
# 1                  False           False               False
# 2                  False           False               False
# 3                  False           False               False
# 4                  False           False               False
# ..                   ...             ...                 ...
# 457                False           False               False
# 458                False           False               False
# 459                False           False               False
# 460                False           False               False
# 461                False           False               False
#
# [462 rows x 15 columns]

# %% [markdown]
# ¿Cómo podemos transformar toda esta información para que sea más legible?

# %%
# Una forma bien simple sería usando 
datos.isna().sum()
# Out:
# ID                         0
# Age                        0
# Gender                     0
# Bedtime                    0
# Wakeup time                0
# Sleep duration             0
# Sleep efficiency           0
# REM sleep percentage       0
# Deep sleep percentage      0
# Light sleep percentage     0
# Awakenings                20
# Caffeine consumption      25
# Alcohol consumption       15
# Smoking status             0
# Exercise frequency         6
# dtype: int64

# %%
# De ahi sabemos que Despertares, Consumo de cafeina, Consumo de alcohol y Frecuencia de ejercicio tienen datos faltantes

# %%
# Esto nos da lo mismo (null es comun en SQL, NaN se usa en NumPy)
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# ¿Qué podríamos hacer con todos estos datos faltantes?

# %%
# Una posibilidad es usar dropna() 
# ¿Qué les parece que hace esta función? 
# ¿Cuántas filas teniamos antes y cuántas tenemos ahora? ¿Cuáles son las ventajas y desventajas de esto?

datos.dropna()
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      12         0.0
# 1                       28                      53         3.0
# 2                       70                      10         1.0
# 3                       25                      52         3.0
# 4                       55                      18         3.0
# ..                     ...                     ...         ...
# 457                     63                      15         1.0
# 458                     60                      22         3.0
# 459                     67                      13         4.0
# 460                     52                      20         0.0
# 461                     20                      53         3.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 0                     0.0                  0.0            Yes
# 1                     0.0                  3.0            Yes
# 2                     0.0                  0.0             No
# 3                    50.0                  5.0            Yes
# 4                     0.0                  3.0             No
# ..                    ...                  ...            ...
# 457                  75.0                  0.0            Yes
# 458                   0.0                  0.0             No
# 459                   0.0                  1.0             No
# 460                  50.0                  0.0             No
# 461                   0.0                  1.0            Yes
#
#      Exercise frequency
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   1.0
# 4                   3.0
# ..                  ...
# 457                 2.0
# 458                 3.0
# 459                 3.0
# 460                 0.0
# 461                 3.0
#
# [397 rows x 15 columns]

# %%
# Otra posibilidad es eliminar las columnas con datos faltantes, de forma de no perder participantes. ¿Cuáles son las ventajas y desventajas de esto?
datos.dropna(axis="columns")
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage Smoking status
# 0                       70                      12            Yes
# 1                       28                      53            Yes
# 2                       70                      10             No
# 3                       25                      52            Yes
# 4                       55                      18             No
# ..                     ...                     ...            ...
# 457                     63                      15            Yes
# 458                     60                      22             No
# 459                     67                      13             No
# 460                     52                      20             No
# 461                     20                      53            Yes
#
# [462 rows x 11 columns]

# %% [markdown]
# Otra opción es hacer una combinación de estas dos posibilidades. Por ejemplo, eliminar las columnas con muchos datos faltantes (e.g. Awakenings y Caffeine compsumption) y recien luego de eso eliminar las filas que tengan algun dato perdido.
#
# De esa forma no pierdo tantas filas ni tantas columnas.

# %%
datos1 = datos.drop(columns=["Awakenings", "Caffeine consumption"])
datos2 = datos1.dropna()
datos2

# En un rato vamos a ver que hay formas más eficientes y ordenadas de encadenar comandos como estos.
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Alcohol consumption  \
# 0                       70                      12                  0.0
# 1                       28                      53                  3.0
# 2                       70                      10                  0.0
# 3                       25                      52                  5.0
# 4                       55                      18                  3.0
# ..                     ...                     ...                  ...
# 457                     63                      15                  0.0
# 458                     60                      22                  0.0
# 459                     67                      13                  1.0
# 460                     52                      20                  0.0
# 461                     20                      53                  1.0
#
#     Smoking status  Exercise frequency
# 0              Yes                 3.0
# 1              Yes                 3.0
# 2               No                 3.0
# 3              Yes                 1.0
# 4               No                 3.0
# ..             ...                 ...
# 457            Yes                 2.0
# 458             No                 3.0
# 459             No                 3.0
# 460             No                 0.0
# 461            Yes                 3.0
#
# [441 rows x 13 columns]

# %% [markdown]
# También podríamos elegir no eliminar los casos, sino reemplazar los datos faltantes con un valor (e.g. cero). A esto se lo llama "imputación de datos faltantes".
#
# Lo podemos hacer con fillna()

# %%
datos.fillna(0)
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      12         0.0
# 1                       28                      53         3.0
# 2                       70                      10         1.0
# 3                       25                      52         3.0
# 4                       55                      18         3.0
# ..                     ...                     ...         ...
# 457                     63                      15         1.0
# 458                     60                      22         3.0
# 459                     67                      13         4.0
# 460                     52                      20         0.0
# 461                     20                      53         3.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 0                     0.0                  0.0            Yes
# 1                     0.0                  3.0            Yes
# 2                     0.0                  0.0             No
# 3                    50.0                  5.0            Yes
# 4                     0.0                  3.0             No
# ..                    ...                  ...            ...
# 457                  75.0                  0.0            Yes
# 458                   0.0                  0.0             No
# 459                   0.0                  1.0             No
# 460                  50.0                  0.0             No
# 461                   0.0                  1.0            Yes
#
#      Exercise frequency
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   1.0
# 4                   3.0
# ..                  ...
# 457                 2.0
# 458                 3.0
# 459                 3.0
# 460                 0.0
# 461                 3.0
#
# [462 rows x 15 columns]

# %%
# Chequeamos
filas_con_nan = datos.isna().any(axis=1)
datos[filas_con_nan]
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 19    20   52    Male  2021-12-03 00:30:00  2021-12-03 07:30:00
# 20    21   24    Male  2021-05-02 00:00:00  2021-05-02 08:00:00
# 24    25   24    Male  2021-09-16 00:00:00  2021-09-16 07:00:00
# 26    27   36  Female  2021-06-18 00:00:00  2021-06-18 07:00:00
# ..   ...  ...     ...                  ...                  ...
# 440  441   28  Female  2021-02-06 21:00:00  2021-02-06 05:00:00
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 446  447   23    Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 454  337   50  Female  2021-07-20 22:00:00  2021-07-20 05:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 5               7.5              0.90                    23
# 19              7.0              0.89                    28
# 20              8.0              0.83                    15
# 24              7.0              0.88                    15
# 26              7.0              0.95                    28
# ..              ...               ...                   ...
# 440             8.0              0.88                    22
# 442             7.0              0.68                    23
# 446             7.0              0.50                    15
# 449             8.5              0.55                    20
# 454             7.0              0.90                    22
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 5                       60                      17         0.0
# 19                      52                      20         NaN
# 20                      75                      10         3.0
# 24                      75                      10         1.0
# 26                      55                      17         0.0
# ..                     ...                     ...         ...
# 440                     63                      15         0.0
# 442                     22                      55         1.0
# 446                     40                      45         2.0
# 449                     32                      48         1.0
# 454                     58                      20         1.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 5                     NaN                  0.0             No
# 19                   50.0                  0.0            Yes
# 20                    0.0                  NaN             No
# 24                    NaN                  5.0             No
# 26                    NaN                  0.0             No
# ..                    ...                  ...            ...
# 440                  75.0                  NaN            Yes
# 442                   NaN                  4.0             No
# 446                   0.0                  4.0            Yes
# 449                   NaN                  3.0            Yes
# 454                   0.0                  NaN             No
#
#      Exercise frequency
# 5                   1.0
# 19                  3.0
# 20                  2.0
# 24                  2.0
# 26                  1.0
# ..                  ...
# 440                 2.0
# 442                 1.0
# 446                 NaN
# 449                 0.0
# 454                 5.0
#
# [65 rows x 15 columns]

# %%
datos0 = datos.fillna(0)
datos0[filas_con_nan]
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 19    20   52    Male  2021-12-03 00:30:00  2021-12-03 07:30:00
# 20    21   24    Male  2021-05-02 00:00:00  2021-05-02 08:00:00
# 24    25   24    Male  2021-09-16 00:00:00  2021-09-16 07:00:00
# 26    27   36  Female  2021-06-18 00:00:00  2021-06-18 07:00:00
# ..   ...  ...     ...                  ...                  ...
# 440  441   28  Female  2021-02-06 21:00:00  2021-02-06 05:00:00
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 446  447   23    Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 454  337   50  Female  2021-07-20 22:00:00  2021-07-20 05:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 5               7.5              0.90                    23
# 19              7.0              0.89                    28
# 20              8.0              0.83                    15
# 24              7.0              0.88                    15
# 26              7.0              0.95                    28
# ..              ...               ...                   ...
# 440             8.0              0.88                    22
# 442             7.0              0.68                    23
# 446             7.0              0.50                    15
# 449             8.5              0.55                    20
# 454             7.0              0.90                    22
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 5                       60                      17         0.0
# 19                      52                      20         0.0
# 20                      75                      10         3.0
# 24                      75                      10         1.0
# 26                      55                      17         0.0
# ..                     ...                     ...         ...
# 440                     63                      15         0.0
# 442                     22                      55         1.0
# 446                     40                      45         2.0
# 449                     32                      48         1.0
# 454                     58                      20         1.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 5                     0.0                  0.0             No
# 19                   50.0                  0.0            Yes
# 20                    0.0                  0.0             No
# 24                    0.0                  5.0             No
# 26                    0.0                  0.0             No
# ..                    ...                  ...            ...
# 440                  75.0                  0.0            Yes
# 442                   0.0                  4.0             No
# 446                   0.0                  4.0            Yes
# 449                   0.0                  3.0            Yes
# 454                   0.0                  0.0             No
#
#      Exercise frequency
# 5                   1.0
# 19                  3.0
# 20                  2.0
# 24                  2.0
# 26                  1.0
# ..                  ...
# 440                 2.0
# 442                 1.0
# 446                 0.0
# 449                 0.0
# 454                 5.0
#
# [65 rows x 15 columns]

# %% [markdown]
# ¿Qué opinamos de esto? ¿Se puede usar en todos los casos? ¿Qué otras formas se te ocurren?

# %%
# Una forma super sencilla (pero no infalible) es reemplazar el dato perdido por la media o la mediana poblacional 
# (Capaz la mediana es mejor porque te va a buscar un dato existente)

# Ahora cual usamos??
#datos.fillna(mean)
#datos.fillna(datos.mean())

#Veamos el help... 
datos.fillna(datos.median(numeric_only=True))
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      12         0.0
# 1                       28                      53         3.0
# 2                       70                      10         1.0
# 3                       25                      52         3.0
# 4                       55                      18         3.0
# ..                     ...                     ...         ...
# 457                     63                      15         1.0
# 458                     60                      22         3.0
# 459                     67                      13         4.0
# 460                     52                      20         0.0
# 461                     20                      53         3.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 0                     0.0                  0.0            Yes
# 1                     0.0                  3.0            Yes
# 2                     0.0                  0.0             No
# 3                    50.0                  5.0            Yes
# 4                     0.0                  3.0             No
# ..                    ...                  ...            ...
# 457                  75.0                  0.0            Yes
# 458                   0.0                  0.0             No
# 459                   0.0                  1.0             No
# 460                  50.0                  0.0             No
# 461                   0.0                  1.0            Yes
#
#      Exercise frequency
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   1.0
# 4                   3.0
# ..                  ...
# 457                 2.0
# 458                 3.0
# 459                 3.0
# 460                 0.0
# 461                 3.0
#
# [462 rows x 15 columns]

# %%
# Tenemos que pasarle un vector de valores para usar en cada columna, el vector lo generamos asi:
datos.mean(numeric_only=True)   # No podemos tomar media de variables no-numericas
# Out:
# ID                        225.833333
# Age                        40.222944
# Sleep duration              7.470779
# Sleep efficiency            0.787771
# REM sleep percentage       22.614719
# Deep sleep percentage      52.668831
# Light sleep percentage     24.716450
# Awakenings                  1.656109
# Caffeine consumption       23.512586
# Alcohol consumption         1.170022
# Exercise frequency          1.800439
# dtype: float64

# %% [markdown]
# Podemos resolverlo utilizando funciones que ya vimos, modificando la variable index.

# %%
# Esto va a funcionar?? fillna solo actúa en columnas numéricas??
datosMedia = datos.fillna(datos.mean(numeric_only=True))
datosMedia[filas_con_nan]
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 5      6   36  Female  2021-07-01 21:00:00  2021-07-01 04:30:00
# 19    20   52    Male  2021-12-03 00:30:00  2021-12-03 07:30:00
# 20    21   24    Male  2021-05-02 00:00:00  2021-05-02 08:00:00
# 24    25   24    Male  2021-09-16 00:00:00  2021-09-16 07:00:00
# 26    27   36  Female  2021-06-18 00:00:00  2021-06-18 07:00:00
# ..   ...  ...     ...                  ...                  ...
# 440  441   28  Female  2021-02-06 21:00:00  2021-02-06 05:00:00
# 442  443   27  Female  2021-02-06 01:30:00  2021-02-06 08:30:00
# 446  447   23    Male  2021-04-21 00:00:00  2021-04-21 07:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 454  337   50  Female  2021-07-20 22:00:00  2021-07-20 05:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 5               7.5              0.90                    23
# 19              7.0              0.89                    28
# 20              8.0              0.83                    15
# 24              7.0              0.88                    15
# 26              7.0              0.95                    28
# ..              ...               ...                   ...
# 440             8.0              0.88                    22
# 442             7.0              0.68                    23
# 446             7.0              0.50                    15
# 449             8.5              0.55                    20
# 454             7.0              0.90                    22
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 5                       60                      17    0.000000
# 19                      52                      20    1.656109
# 20                      75                      10    3.000000
# 24                      75                      10    1.000000
# 26                      55                      17    0.000000
# ..                     ...                     ...         ...
# 440                     63                      15    0.000000
# 442                     22                      55    1.000000
# 446                     40                      45    2.000000
# 449                     32                      48    1.000000
# 454                     58                      20    1.000000
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 5               23.512586             0.000000             No
# 19              50.000000             0.000000            Yes
# 20               0.000000             1.170022             No
# 24              23.512586             5.000000             No
# 26              23.512586             0.000000             No
# ..                    ...                  ...            ...
# 440             75.000000             1.170022            Yes
# 442             23.512586             4.000000             No
# 446              0.000000             4.000000            Yes
# 449             23.512586             3.000000            Yes
# 454              0.000000             1.170022             No
#
#      Exercise frequency
# 5              1.000000
# 19             3.000000
# 20             2.000000
# 24             2.000000
# 26             1.000000
# ..                  ...
# 440            2.000000
# 442            1.000000
# 446            1.800439
# 449            0.000000
# 454            5.000000
#
# [65 rows x 15 columns]

# %% [markdown]
# En pocas palabras:
# - Completamos con 0 si pensamos que no figura el dato porque no hay o no corresponde. Por ejemplo, en información de alimentos y bebidas, el porcentaje de alcohol puede figurar como NA.
# - Completamos con el promedio si pensamos que se perdió el dato y queremos afectar lo menos posible los modelos (o una técnica más avanzada sería predecir ese valor usando otras variables).
#
# Cómo completarías estos datos faltantes?
# - Metros cuadrados de un departamento.
# - Cantidad de votos recibidos por un partido en la elección anterior.
# - Cantidad de ventas realizadas de cierto producto en cierto día.
# - Altura de un paciente.

# %% [markdown]
# ### Ejercicio
# 1. Examinar el dataset de eficiencia MPG y hacer algo con los datos faltantes. ¿Qué harían si no queremos eliminar filas?
# 2. Examinar el dataset de pingüinos y hacer algo con los datos faltantes.

# %%
penguins = sns.load_dataset("penguins")
mpg = sns.load_dataset("mpg")

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg_clean = mpg.fillna(mpg.mean(numeric_only=True))
mpg_clean.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
penguins.isna().sum()
filas_con_nan_penguins = penguins.isna().any(axis=1)
penguins[filas_con_nan_penguins]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN
# 336       4875.0  NaN
# 339          NaN  NaN

# %%
penguins_clean = penguins.dropna()

# %% [markdown]
# ### 2.b Eliminar datos duplicados
#
# En muchos casos puede suceder que haya datos duplicados en nuestro dataset. ¿Se les ocurren ejemplos?
#
# Para identificarlos, podemos usar `duplicated()`. ¿Qué está haciendo esta función?

# %%
datos.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 457     True
# 458     True
# 459     True
# 460     True
# 461    False
# Length: 462, dtype: bool

# %%
# Cuántos datos duplicados hay?
datos.duplicated().sum()
# Out:
# np.int64(8)

# %%
# Es la misma fila repetida muchas veces o varias filas duplicadas?
# Podemos usar el viejo y querido value_counts()...
datos.value_counts()
# Out:
# ID   Age  Gender  Bedtime              Wakeup time          Sleep duration  Sleep efficiency  REM sleep percentage  Deep sleep percentage  Light sleep percentage  Awakenings  Caffeine consumption  Alcohol consumption  Smoking status  Exercise frequency
# 102  53   Male    2021-01-28 01:00:00  2021-01-28 09:30:00  8.5             0.71              20                    67                     13                      4.0         0.0                   1.0                  No              3.0                   2
# 154  41   Male    2021-07-01 02:30:00  2021-07-01 10:00:00  7.5             0.70              22                    59                     19                      3.0         0.0                   0.0                  No              3.0                   2
# 197  30   Female  2021-08-05 00:00:00  2021-08-05 08:00:00  8.0             0.94              22                    63                     15                      1.0         75.0                  0.0                  Yes             2.0                   2
# 291  54   Male    2021-01-20 22:30:00  2021-01-20 06:30:00  8.0             0.84              18                    60                     22                      3.0         0.0                   0.0                  No              3.0                   2
# 300  22   Male    2021-04-24 21:30:00  2021-04-24 05:30:00  8.0             0.60              27                    20                     53                      4.0         0.0                   4.0                  No              3.0                   2
#                                                                                                                                                                                                                                                                ..
# 449  52   Male    2021-03-31 21:00:00  2021-03-31 03:00:00  6.0             0.74              28                    57                     15                      4.0         25.0                  0.0                  No              3.0                   1
# 451  45   Male    2021-07-29 21:00:00  2021-07-29 04:00:00  7.0             0.76              18                    72                     10                      3.0         0.0                   0.0                  No              3.0                   1
# 452  18   Male    2021-03-17 02:30:00  2021-03-17 10:00:00  7.5             0.63              22                    23                     55                      1.0         50.0                  0.0                  No              1.0                   1
# 40   58   Female  2021-03-26 02:00:00  2021-03-26 09:00:00  7.0             0.63              22                    23                     55                      3.0         50.0                  3.0                  No              0.0                   1
# 31   24   Male    2021-08-10 00:00:00  2021-08-10 07:00:00  7.0             0.57              27                    20                     53                      3.0         0.0                   1.0                  Yes             3.0                   1
# Name: count, Length: 390, dtype: int64

# %% [markdown]
# Para eliminarlos, podríamos usar `drop_duplicates()`

# %%
# O vemos las filas
datos[datos.duplicated()]

# O keep = False para ver todas las filas duplicadas, todas las veces que aparecen
datos[datos.duplicated(keep = False)]
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 101  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 153  154   41    Male  2021-07-01 02:30:00  2021-07-01 10:00:00
# 196  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 290  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 299  300   22    Male  2021-04-24 21:30:00  2021-04-24 05:30:00
# 332  333   12  Female  2021-11-01 01:00:00  2021-11-01 10:00:00
# 336  337   50  Female  2021-07-20 22:00:00  2021-07-20 05:00:00
# 398  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 452  300   22    Male  2021-04-24 21:30:00  2021-04-24 05:30:00
# 454  337   50  Female  2021-07-20 22:00:00  2021-07-20 05:00:00
# 455  333   12  Female  2021-11-01 01:00:00  2021-11-01 10:00:00
# 456  154   41    Male  2021-07-01 02:30:00  2021-07-01 10:00:00
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 101             8.5              0.71                    20
# 153             7.5              0.70                    22
# 196             8.0              0.94                    22
# 290             8.0              0.84                    18
# 299             8.0              0.60                    27
# 332             9.0              0.56                    18
# 336             7.0              0.90                    22
# 398             7.0              0.91                    28
# 452             8.0              0.60                    27
# 454             7.0              0.90                    22
# 455             9.0              0.56                    18
# 456             7.5              0.70                    22
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 101                     67                      13         4.0
# 153                     59                      19         3.0
# 196                     63                      15         1.0
# 290                     60                      22         3.0
# 299                     20                      53         4.0
# 332                     35                      47         1.0
# 336                     58                      20         1.0
# 398                     52                      20         0.0
# 452                     20                      53         4.0
# 454                     58                      20         1.0
# 455                     35                      47         1.0
# 456                     59                      19         3.0
# 457                     63                      15         1.0
# 458                     60                      22         3.0
# 459                     67                      13         4.0
# 460                     52                      20         0.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 101                   0.0                  1.0             No
# 153                   0.0                  0.0             No
# 196                  75.0                  0.0            Yes
# 290                   0.0                  0.0             No
# 299                   0.0                  4.0             No
# 332                   0.0                  0.0             No
# 336                   0.0                  NaN             No
# 398                  50.0                  0.0             No
# 452                   0.0                  4.0             No
# 454                   0.0                  NaN             No
# 455                   0.0                  0.0             No
# 456                   0.0                  0.0             No
# 457                  75.0                  0.0            Yes
# 458                   0.0                  0.0             No
# 459                   0.0                  1.0             No
# 460                  50.0                  0.0             No
#
#      Exercise frequency
# 101                 3.0
# 153                 3.0
# 196                 2.0
# 290                 3.0
# 299                 3.0
# 332                 0.0
# 336                 5.0
# 398                 0.0
# 452                 3.0
# 454                 5.0
# 455                 0.0
# 456                 3.0
# 457                 2.0
# 458                 3.0
# 459                 3.0
# 460                 0.0

# %%
# Eliminamos duplicados
datos.drop_duplicates()
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
# 453   40   58  Female  2021-03-26 02:00:00  2021-03-26 09:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 449             8.5              0.55                    20
# 450             7.0              0.76                    18
# 451             7.5              0.63                    22
# 453             7.0              0.63                    22
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      12         0.0
# 1                       28                      53         3.0
# 2                       70                      10         1.0
# 3                       25                      52         3.0
# 4                       55                      18         3.0
# ..                     ...                     ...         ...
# 449                     32                      48         1.0
# 450                     72                      10         3.0
# 451                     23                      55         1.0
# 453                     23                      55         3.0
# 461                     20                      53         3.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 0                     0.0                  0.0            Yes
# 1                     0.0                  3.0            Yes
# 2                     0.0                  0.0             No
# 3                    50.0                  5.0            Yes
# 4                     0.0                  3.0             No
# ..                    ...                  ...            ...
# 449                   NaN                  3.0            Yes
# 450                   0.0                  0.0             No
# 451                  50.0                  0.0             No
# 453                  50.0                  3.0             No
# 461                   0.0                  1.0            Yes
#
#      Exercise frequency
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   1.0
# 4                   3.0
# ..                  ...
# 449                 0.0
# 450                 3.0
# 451                 1.0
# 453                 0.0
# 461                 3.0
#
# [454 rows x 15 columns]

# %% [markdown]
# ¿Qué hace esta función? ¿Qué valores se queda y cuáles elimina?
#
# Por defecto, se queda con el primer caso, pero podemos indicarle que se quede con el último por ej:

# %%
datos.drop_duplicates(keep = "last")
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 457  197   30  Female  2021-08-05 00:00:00  2021-08-05 08:00:00
# 458  291   54    Male  2021-01-20 22:30:00  2021-01-20 06:30:00
# 459  102   53    Male  2021-01-28 01:00:00  2021-01-28 09:30:00
# 460  399   30  Female  2021-07-21 01:00:00  2021-07-21 08:00:00
# 461   31   24    Male  2021-08-10 00:00:00  2021-08-10 07:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# 2               8.0              0.89                    20
# 3               6.0              0.51                    23
# 4               8.0              0.76                    27
# ..              ...               ...                   ...
# 457             8.0              0.94                    22
# 458             8.0              0.84                    18
# 459             8.5              0.71                    20
# 460             7.0              0.91                    28
# 461             7.0              0.57                    27
#
#      Deep sleep percentage  Light sleep percentage  Awakenings  \
# 0                       70                      12         0.0
# 1                       28                      53         3.0
# 2                       70                      10         1.0
# 3                       25                      52         3.0
# 4                       55                      18         3.0
# ..                     ...                     ...         ...
# 457                     63                      15         1.0
# 458                     60                      22         3.0
# 459                     67                      13         4.0
# 460                     52                      20         0.0
# 461                     20                      53         3.0
#
#      Caffeine consumption  Alcohol consumption Smoking status  \
# 0                     0.0                  0.0            Yes
# 1                     0.0                  3.0            Yes
# 2                     0.0                  0.0             No
# 3                    50.0                  5.0            Yes
# 4                     0.0                  3.0             No
# ..                    ...                  ...            ...
# 457                  75.0                  0.0            Yes
# 458                   0.0                  0.0             No
# 459                   0.0                  1.0             No
# 460                  50.0                  0.0             No
# 461                   0.0                  1.0            Yes
#
#      Exercise frequency
# 0                   3.0
# 1                   3.0
# 2                   3.0
# 3                   1.0
# 4                   3.0
# ..                  ...
# 457                 2.0
# 458                 3.0
# 459                 3.0
# 460                 0.0
# 461                 3.0
#
# [454 rows x 15 columns]

# %% [markdown]
# **Pregunta:** Si tuvieramos sujetos duplicados, es decir, completaron dos veces la misma encuesta, pero respondieron distinto, cómo lo podríamos saber?

# %% [markdown]
# ### 2.c Resetear el index
#
# Volvamos a los pingüinos.
# Una vez que eliminamos filas por el motivo que sea, nos van a quedar índices salteados. En muchos casos no es importante conservar los índices originales, y es conveniente numerar todo de 0 a N-1.

# %%
penguinsClean = penguins.dropna()
penguinsClean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
# Reseteamos los índices 
penguinsClean = penguinsClean.reset_index()
penguinsClean   # Vemos que creó una nueva columna con los índices viejos
# Out:
#      index species     island  bill_length_mm  bill_depth_mm  \
# 0        0  Adelie  Torgersen            39.1           18.7
# 1        1  Adelie  Torgersen            39.5           17.4
# 2        2  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen            36.7           19.3
# 4        5  Adelie  Torgersen            39.3           20.6
# ..     ...     ...        ...             ...            ...
# 328    338  Gentoo     Biscoe            47.2           13.7
# 329    340  Gentoo     Biscoe            46.8           14.3
# 330    341  Gentoo     Biscoe            50.4           15.7
# 331    342  Gentoo     Biscoe            45.2           14.8
# 332    343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    Male
# 1                186.0       3800.0  Female
# 2                195.0       3250.0  Female
# 3                193.0       3450.0  Female
# 4                190.0       3650.0    Male
# ..                 ...          ...     ...
# 328              214.0       4925.0  Female
# 329              215.0       4850.0  Female
# 330              222.0       5750.0    Male
# 331              212.0       5200.0  Female
# 332              213.0       5400.0    Male
#
# [333 rows x 8 columns]

# %%
# De esta forma solo nos quedamos con lo síndices nuevos.
penguinsClean = penguinsClean.reset_index(drop = True)
penguinsClean
# Out:
#      index species     island  bill_length_mm  bill_depth_mm  \
# 0        0  Adelie  Torgersen            39.1           18.7
# 1        1  Adelie  Torgersen            39.5           17.4
# 2        2  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen            36.7           19.3
# 4        5  Adelie  Torgersen            39.3           20.6
# ..     ...     ...        ...             ...            ...
# 328    338  Gentoo     Biscoe            47.2           13.7
# 329    340  Gentoo     Biscoe            46.8           14.3
# 330    341  Gentoo     Biscoe            50.4           15.7
# 331    342  Gentoo     Biscoe            45.2           14.8
# 332    343  Gentoo     Biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g     sex
# 0                181.0       3750.0    Male
# 1                186.0       3800.0  Female
# 2                195.0       3250.0  Female
# 3                193.0       3450.0  Female
# 4                190.0       3650.0    Male
# ..                 ...          ...     ...
# 328              214.0       4925.0  Female
# 329              215.0       4850.0  Female
# 330              222.0       5750.0    Male
# 331              212.0       5200.0  Female
# 332              213.0       5400.0    Male
#
# [333 rows x 8 columns]

# %%
# No funciono??
# Es que tenemos que empezar todo de nuevo!

penguinsClean = penguins.dropna()
penguinsClean = penguinsClean.reset_index(drop = True)
penguinsClean
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 328  Gentoo     Biscoe            47.2           13.7              214.0
# 329  Gentoo     Biscoe            46.8           14.3              215.0
# 330  Gentoo     Biscoe            50.4           15.7              222.0
# 331  Gentoo     Biscoe            45.2           14.8              212.0
# 332  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3         3450.0  Female
# 4         3650.0    Male
# ..           ...     ...
# 328       4925.0  Female
# 329       4850.0  Female
# 330       5750.0    Male
# 331       5200.0  Female
# 332       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## Encadenar todos estos métodos

# %% [markdown]
# Esta forma de ir modificando un dataset no es muy práctica.
#
# Por ejemplo si ejecutamos varias veces el mismo comando, obtendremos cada vez algo distinto.
#
# Una solución es encadenar métodos para hacer el código más legible y fácil de reusar. Y más eficiente también.

# %%
penguinsClean = penguins.dropna().reset_index()
penguinsClean.head()
# Out:
#    index species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      0  Adelie  Torgersen            39.1           18.7              181.0
# 1      1  Adelie  Torgersen            39.5           17.4              186.0
# 2      2  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen            36.7           19.3              193.0
# 4      5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %%
# Si queremos eliminar la columna de índices viejos
penguinsClean = penguins.dropna().reset_index(drop = True)
penguinsClean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %%
# Ahora sumamos 1 a todos los indices
penguinsClean.index += 1
penguinsClean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1  Adelie  Torgersen            39.1           18.7              181.0
# 2  Adelie  Torgersen            39.5           17.4              186.0
# 3  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 1       3750.0    Male
# 2       3800.0  Female
# 3       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# Podemos encadenar estas operaciones?

# %%
#penguinsClean = penguins.dropna().reset_index(drop = True).index += 1  nop

# %%
# Eso dio error. Y así?
penguins.dropna().reset_index(drop = True).index += 1
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# No sabemos dónde lo guardó...

# %% [markdown]
# Para encadenar esta operación vamos a utilizar `.rename(index = dict o function)`.
#
# Podemos pasarle también un diccionario o una función.

# %% [markdown]
# ### Ejercicio
# 1. Cambiar el índice 0 a "Cero".
# 2. Tomas la raíz cuadradada de los índices (del dataset penguinsClean original sin "Cero").

# %%
penguinsClean = penguins.dropna().reset_index(drop = True)
penguinsClean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen            36.7           19.3              193.0
# 4  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3       3450.0  Female
# 4       3650.0    Male

# %%
penguinsCleanCero = penguinsClean.rename(index={0:"Cero"})
penguinsCleanCero
# Out:
#      species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# Cero  Adelie  Torgersen            39.1           18.7              181.0
# 1     Adelie  Torgersen            39.5           17.4              186.0
# 2     Adelie  Torgersen            40.3           18.0              195.0
# 3     Adelie  Torgersen            36.7           19.3              193.0
# 4     Adelie  Torgersen            39.3           20.6              190.0
# ...      ...        ...             ...            ...                ...
# 328   Gentoo     Biscoe            47.2           13.7              214.0
# 329   Gentoo     Biscoe            46.8           14.3              215.0
# 330   Gentoo     Biscoe            50.4           15.7              222.0
# 331   Gentoo     Biscoe            45.2           14.8              212.0
# 332   Gentoo     Biscoe            49.9           16.1              213.0
#
#       body_mass_g     sex
# Cero       3750.0    Male
# 1          3800.0  Female
# 2          3250.0  Female
# 3          3450.0  Female
# 4          3650.0    Male
# ...           ...     ...
# 328        4925.0  Female
# 329        4850.0  Female
# 330        5750.0    Male
# 331        5200.0  Female
# 332        5400.0    Male
#
# [333 rows x 7 columns]

# %%
import math

penguinsClean = penguinsClean.reset_index(drop = True)
penguinsClean = penguinsClean.rename(index= lambda x: math.sqrt(x))

penguinsClean
# Out:
#           species     island  bill_length_mm  bill_depth_mm  \
# 0.000000   Adelie  Torgersen            39.1           18.7
# 1.000000   Adelie  Torgersen            39.5           17.4
# 1.414214   Adelie  Torgersen            40.3           18.0
# 1.732051   Adelie  Torgersen            36.7           19.3
# 2.000000   Adelie  Torgersen            39.3           20.6
# ...           ...        ...             ...            ...
# 18.110770  Gentoo     Biscoe            47.2           13.7
# 18.138357  Gentoo     Biscoe            46.8           14.3
# 18.165902  Gentoo     Biscoe            50.4           15.7
# 18.193405  Gentoo     Biscoe            45.2           14.8
# 18.220867  Gentoo     Biscoe            49.9           16.1
#
#            flipper_length_mm  body_mass_g     sex
# 0.000000               181.0       3750.0    Male
# 1.000000               186.0       3800.0  Female
# 1.414214               195.0       3250.0  Female
# 1.732051               193.0       3450.0  Female
# 2.000000               190.0       3650.0    Male
# ...                      ...          ...     ...
# 18.110770              214.0       4925.0  Female
# 18.138357              215.0       4850.0  Female
# 18.165902              222.0       5750.0    Male
# 18.193405              212.0       5200.0  Female
# 18.220867              213.0       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ### Ejemplo: sumar uno a todos los índices

# %% [markdown]
# Para sumar uno a todos los índices no podemos hacer penguinsClean.rename(index = + 1).
#
# Podemos definir primero nuestra propia función.

# %%
def sumaUno(x):
    return(x+1)
penguinsClean= penguinsClean.reset_index(drop=True)
penguinsClean.rename(index = sumaUno)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 329  Gentoo     Biscoe            47.2           13.7              214.0
# 330  Gentoo     Biscoe            46.8           14.3              215.0
# 331  Gentoo     Biscoe            50.4           15.7              222.0
# 332  Gentoo     Biscoe            45.2           14.8              212.0
# 333  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 1         3750.0    Male
# 2         3800.0  Female
# 3         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 329       4925.0  Female
# 330       4850.0  Female
# 331       5750.0    Male
# 332       5200.0  Female
# 333       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## 3. Funciones lambda
# Resulta engorroso definir una función para usarla solamente dentro del rename.
#
# Las **funciones lambda** nos permiten definir funciones anónimas "al vuelo".
#
# La sintaxis es
#
# `lambda arguments : expression`

# %%
# Ejemplo
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %%
# Ejemplo
x = lambda a, b : a * b
print(x(5, 6))
# Out:
# 30

# %%
# Ejemplo
x = lambda a : a + 1
print(x(5))
# Out:
# 6

# %%
# Ahora sí!
penguinsClean.rename(index = lambda a : a + 1)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 329  Gentoo     Biscoe            47.2           13.7              214.0
# 330  Gentoo     Biscoe            46.8           14.3              215.0
# 331  Gentoo     Biscoe            50.4           15.7              222.0
# 332  Gentoo     Biscoe            45.2           14.8              212.0
# 333  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 1         3750.0    Male
# 2         3800.0  Female
# 3         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 329       4925.0  Female
# 330       4850.0  Female
# 331       5750.0    Male
# 332       5200.0  Female
# 333       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# Esta operación la podemos encadenar con las anteriores:

# %%
penguinsClean = penguins.dropna().reset_index(drop = True).rename(index = lambda a : a + 1)
penguinsClean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1  Adelie  Torgersen            39.1           18.7              181.0
# 2  Adelie  Torgersen            39.5           17.4              186.0
# 3  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 1       3750.0    Male
# 2       3800.0  Female
# 3       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# O si queremos cada metodo en una linea nueva
penguinsClean = (
    penguins.dropna()
    .reset_index(drop = True)
    .rename(index = lambda a : a + 1)
)
penguinsClean.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1  Adelie  Torgersen            39.1           18.7              181.0
# 2  Adelie  Torgersen            39.5           17.4              186.0
# 3  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 1       3750.0    Male
# 2       3800.0  Female
# 3       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# ### Ejercicio
# Utilizando funciones lambda:
# 1. Encadenar un método más para agregar "_orig" a los nombres de todas las columnas.
# 2. Encadenar un método más para reemplazar todos _ por - en los nombres de columnas.

# %%
# Sugerencia 1
"hola" + "chau"
# Out:
# 'holachau'

# %%
# Sugerencia 2
str.replace("abcndjaA", "a", "oo")
# Out:
# 'oobcndjooA'

# %%
agregar_orig = lambda x: x + "_orig"
reemplazar_= lambda x: str.replace(x,"_","-")

penguinsClean.head()
penguinsClean.rename(columns=agregar_orig).rename(columns=reemplazar_)
# Out:
#     species-orig island-orig  bill-length-mm-orig  bill-depth-mm-orig  \
# 1         Adelie   Torgersen                 39.1                18.7
# 2         Adelie   Torgersen                 39.5                17.4
# 3         Adelie   Torgersen                 40.3                18.0
# 4         Adelie   Torgersen                 36.7                19.3
# 5         Adelie   Torgersen                 39.3                20.6
# ..           ...         ...                  ...                 ...
# 329       Gentoo      Biscoe                 47.2                13.7
# 330       Gentoo      Biscoe                 46.8                14.3
# 331       Gentoo      Biscoe                 50.4                15.7
# 332       Gentoo      Biscoe                 45.2                14.8
# 333       Gentoo      Biscoe                 49.9                16.1
#
#      flipper-length-mm-orig  body-mass-g-orig sex-orig
# 1                     181.0            3750.0     Male
# 2                     186.0            3800.0   Female
# 3                     195.0            3250.0   Female
# 4                     193.0            3450.0   Female
# 5                     190.0            3650.0     Male
# ..                      ...               ...      ...
# 329                   214.0            4925.0   Female
# 330                   215.0            4850.0   Female
# 331                   222.0            5750.0     Male
# 332                   212.0            5200.0   Female
# 333                   213.0            5400.0     Male
#
# [333 rows x 7 columns]
